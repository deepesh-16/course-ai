# %%
import numpy as np
import pandas as pd
import nltk
import sklearn
from nltk.stem import PorterStemmer
from apyori import apriori
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ksdee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data=pd.read_csv('./cleaned_related_skills.csv')
data.head()
# Out:
#                         name           related_1                   related_2  \
# 0                a certified   network certified                     laptops
# 1  a certified it technician         n certified           network certified
# 2   a certified professional   network certified   comptia network certified
# 3            a quick learner  product validation  great communication skills
# 4                a1 assessor               ptlls           assessor training
#
#                    related_3                         related_4  \
# 0                n certified                 computer hardware
# 1  comptia network certified           comptia a certification
# 2                n certified  microsoft certified professional
# 3                      vista          good communication skill
# 4                       nvqs                 training delivery
#
#                    related_5           related_6            related_7  \
# 0                  windows 7             comptia      troubleshooting
# 1   a certified professional               mcdst            windows 7
# 2  a certified it technician     troubleshooting            windows 7
# 3              people person  project resourcing  new product release
# 4    training needs analysis            trainers    train the trainer
#
#                related_8               related_9      related_10
# 0  software installation                printers              xp
# 1      computer hardware         computer repair     a certified
# 2       active directory       computer hardware  windows server
# 3           touch typing  excellent communicator  internet savvy
# 4    employer engagement    commercial awareness           fleet

# %%
domain=[]
for i in range(len(data)):
    temp_list=[]
    temp_list.append(str(data.iloc[i]['related_1']))
    temp_list.append(str(data.iloc[i]['related_2']))
    temp_list.append(str(data.iloc[i]['related_3']))
    temp_list.append(str(data.iloc[i]['related_4']))
    temp_list.append(str(data.iloc[i]['related_5']))
    temp_list.append(str(data.iloc[i]['related_6']))
    temp_list.append(str(data.iloc[i]['related_7']))
    temp_list.append(str(data.iloc[i]['related_8']))
    temp_list.append(str(data.iloc[i]['related_9']))
    temp_list.append(str(data.iloc[i]['related_10']))
    domain.append(temp_list)

# %%
domain
# Out:
# [['network certified',
#   'laptops',
#   'n certified',
#   'computer hardware',
#   'windows 7',
#   'comptia',
#   'troubleshooting',
#   'software installation',
#   'printers',
#   'xp'],
#  ['n certified',
#   'network certified',
#   'comptia network certified',
#   'comptia a certification',
#   'a certified professional',
#   'mcdst',
#   'windows 7',
#   'computer hardware',
#   'computer repair',
#   'a certified'],
#  ['network certified',
#   'comptia network certified',
#   'n certified',
#   'microsoft certified professional',
#   'a certified it technician',
#   'troubleshooting',
#   'windows 7',
#   'active directory',
#   'computer hardware',
#   'windows server'],
#  ['product validation',
#   'great communication skills',
#   'vista',
#   'good communication skill',
#   'people person',
#   'project resourcing',
#   'new product release',
#   'touch typing',
#   'excellent communicator',
#   'internet savvy'],
#  ['ptlls',
#   'assessor training',
#   'nvqs',
#   'training delivery',
#   'training needs analysis',
#   'trainers',
#   'train the trainer',
#   'employer engagement',
#   'commercial awareness',
#   'fleet'],
#  ['heijunka',
#   'value stream',
#   'smed',
#   'toyota production system',
#   'kaizen',
#   'kanban',
#   'value stream mapping',
#   'poka yoke',
#   'cellular manufacturing',
#   'jit'],
#  ['visual management systems',
#   'hoshin kanri',
#   'heijunka',
#   'standardized work',
#   'lean manufacturing',
#   'visual management',
#   'jidoka',
#   'standard work',
#   'value stream mapping',
#   'work standardization'],
#  ['aviation',
#   'commercial aviation',
#   'airlines',
#   'aircraft',
#   'b737',
#   'civil aviation',
#   'flight safety',
#   'flights',
#   'line maintenance',
#   'airworthiness'],
#  ['radius',
#   'pcrf',
#   'tacacs',
#   'diameter',
#   'ggsn',
#   'glbp',
#   'stp',
#   'ospf',
#   'etherchannel',
#   'nat'],
#  ['apraxia',
#   'language disorders',
#   'speech therapy',
#   'augmentative communication',
#   'oral motor',
#   'aphasia',
#   'communication disorders',
#   'dysphagia',
#   'phonological disorders',
#   'voice disorders'],
#  ['lcsh',
#   'marc21',
#   'cataloging',
#   'copy cataloging',
#   'oclc connexion',
#   'library of congress classification',
#   'dublin core',
#   'library science',
#   'serials management',
#   'special libraries'],
#  ['multivariate testing',
#   'conversion optimization',
#   'landing page optimization',
#   'web analytics',
#   'google analytics',
#   'website conversion',
#   'omniture',
#   'msn adcenter',
#   'seo',
#   'sem'],
#  ['powerplant',
#   'airframe',
#   'aircraft maintenance',
#   'airworthiness',
#   'aircraft',
#   'aircraft systems',
#   'line maintenance',
#   'aviation',
#   'overhaul',
#   'flight safety'],
#  ['music industry',
#   'record labels',
#   'music publishing',
#   'music licensing',
#   'music',
#   'music supervision',
#   'music production',
#   'music management',
#   'recording',
#   'songwriting'],
#  ['aandr management',
#   'aandr collections',
#   'cash posting',
#   'aging reports',
#   'eob',
#   'denials',
#   'charge entry',
#   'hcfa',
#   'cms1500',
#   'physician coding'],
#  ['aandr analysis',
#   'aandr management',
#   'third party collections',
#   'cash posting',
#   'accounts receivable',
#   'aging reports',
#   'eob',
#   'hcfa',
#   'dso',
#   'denials'],
#  ['aandr analysis',
#   'aandr collections',
#   'cash posting',
#   'aging reports',
#   'eob',
#   'hcfa',
#   'charge entry',
#   'denials',
#   'third party billing',
#   'cms1500'],
#  ['aandv systems',
#   'custom installation',
#   'home audio',
#   'av integration',
#   'home theater',
#   'crestron',
#   'audio visual system design',
#   'projection systems',
#   'extron',
#   'lutron'],
#  ['aandv installation',
#   'av integration',
#   'custom installation',
#   'home audio',
#   'amx',
#   'extron',
#   'projection systems',
#   'lutron',
#   'av',
#   'home theater'],
#  ['ofccp',
#   'eeo',
#   'affirmative action',
#   'eeoandaa compliance',
#   'eeo compliance',
#   'employee relations',
#   'fmla',
#   'human resources',
#   'eeoc',
#   'eeo reporting'],
#  ['hplc',
#   'icpoes',
#   'gc',
#   'icpms',
#   'gcms',
#   'uvandvis',
#   'atomic absorption',
#   'ftir',
#   'analytical chemistry',
#   'icp'],
#  ['purchase ledger',
#   'cima',
#   'sage line50',
#   'double entry',
#   'prepayment',
#   'sage',
#   'sage accounts',
#   'self assessment tax returns',
#   'sole traders',
#   'acca'],
#  ['etl',
#   'data warehousing',
#   'teradata',
#   'unix',
#   'unix shell scripting',
#   'informatica',
#   'autosys',
#   'oracle',
#   'plandsql',
#   'datastage'],
#  ['legal solutions',
#   'galileo',
#   'timeslips',
#   'tabs3',
#   'amicus',
#   'time matters',
#   'amadeus gds',
#   'airline ticketing',
#   'worldspan',
#   'fares'],
#  ['alv',
#   'bapi',
#   'smartforms',
#   'sap badi',
#   'sapscript',
#   'webdynpro',
#   'dialog programming',
#   'abapoo',
#   'abap web dynpro',
#   'user exits'],
#  ['abap',
#   'abapoo',
#   'smartforms',
#   'sap badi',
#   'sap workflow',
#   'bapi',
#   'webdynpro',
#   'user exits',
#   'sap netweaver',
#   'alv'],
#  ['abap',
#   'abap web dynpro',
#   'sap badi',
#   'smartforms',
#   'bapi',
#   'user exits',
#   'alv reports',
#   'sap workflow',
#   'alv',
#   'badis'],
#  ['finite element analysis',
#   'lsdyna',
#   'hypermesh',
#   'optistruct',
#   'ansys',
#   'radioss',
#   'solid mechanics',
#   'ansa',
#   'fracture mechanics',
#   'computational mechanics'],
#  ['asbestos',
#   'leadbased paint',
#   'mold remediation',
#   'mold',
#   'indoor air quality',
#   'remediation',
#   'demolition',
#   'iicrc certified',
#   'structural drying',
#   'fire restoration'],
#  ['kuka',
#   'siemens',
#   'schneider',
#   'fanuc',
#   'omron',
#   'mitsubishi',
#   'plc',
#   'fanuc robots',
#   'automation',
#   'allen bradley'],
#  ['dcs',
#   'profibus',
#   'scada',
#   'process automation',
#   'modbus',
#   'plc',
#   'process control',
#   'automation',
#   'pcs7',
#   'control systems design'],
#  ['analisi dei trend',
#   'tessile',
#   'moda',
#   'maglieria',
#   'abbigliamento sportivo',
#   'beni di lusso',
#   'tessuti',
#   'commercio al dettaglio',
#   'calzature',
#   'vendite allingrosso'],
#  ['abbigliamento',
#   'tessile',
#   'moda',
#   'maglieria',
#   'analisi dei trend',
#   'tessuti',
#   'calzature',
#   'beni di lusso',
#   'commercio al dettaglio',
#   'vendite allingrosso'],
#  ['ocr',
#   'sdl trados',
#   'adobe acrobat',
#   'memoq',
#   'microsoft office',
#   'multiterm',
#   'jaws',
#   'wordfast',
#   'dragon naturally speaking',
#   'sdlx'],
#  ['pareto analysis',
#   'fifo',
#   'whatif analysis',
#   'pareto',
#   'pest analysis',
#   'swot analysis',
#   'pareto charts',
#   'standard costs',
#   'activity based costing',
#   'lean warehousing'],
#  ['small parts',
#   'sonography',
#   'ardms',
#   'ultrasound',
#   'doppler',
#   'abdominal imaging',
#   'diagnostic ultrasound',
#   'breast',
#   'vascular',
#   'thyroid'],
#  ['small parts',
#   'ardms',
#   'doppler',
#   'abdominal',
#   'sonography',
#   'diagnostic ultrasound',
#   'breast imaging',
#   'ultrasound',
#   'phillips',
#   'musculoskeletal radiology'],
#  ['work under pressure',
#   'technical ability',
#   'confidence',
#   'ambition',
#   'target driven',
#   'testing process',
#   'decisioning',
#   'production lines',
#   'detail orientated',
#   'scenography'],
#  ['strong organizational skills',
#   'strong customer service skills',
#   'strong interpersonal skills',
#   'excellent organizational skills',
#   'excellent time management skills',
#   'excellent time management',
#   'detailed oriented',
#   'strong communication skills',
#   'excellent customer service skills',
#   'excellent interpersonal skills'],
#  ['negotiator',
#   'great communication skills',
#   'ability to multitask',
#   'strong work ethic',
#   'work well under pressure',
#   'calm under pressure',
#   'effective time management',
#   'excellent written and oral communication skills',
#   'attentive',
#   'decision maker'],
#  ['excellent time management skills',
#   'dependability',
#   'correspondence',
#   'calendar management',
#   'prioritizing',
#   'diplomatic',
#   'ability to work under pressure',
#   'strong customer service skills',
#   'excellent presentation skills',
#   'ability to multitask'],
#  ['confidence',
#   'selfmotivated',
#   'leading teams',
#   'critical thinking skills',
#   'teamwork skills',
#   'motivating others',
#   'attention to details',
#   'coaching skills',
#   'excellent communication skills',
#   'good communication skills'],
#  ['venditori',
#   'transazioni immobiliari',
#   'investimenti immobiliari',
#   'sviluppo immobiliare',
#   'immobiliare',
#   'immobili commerciali',
#   'trattative',
#   'lusso',
#   'negoziazione contratti',
#   'investimenti'],
#  ['able to work under pressure',
#   'attention to detail',
#   'detail orientation',
#   'organizing',
#   'independent thinker',
#   'flexible working',
#   'prioritization',
#   'highly adaptable',
#   'meeting deadlines',
#   'fast learner'],
#  ['able to multitask',
#   'good interpersonal skills',
#   'tabs3',
#   'critical thinking skills',
#   'highly creative',
#   'drive for results',
#   'good time management',
#   'logical',
#   'customer service oriented',
#   'following directions'],
#  ['able to multitask',
#   'meeting deadlines',
#   'well organised',
#   'multitasker',
#   'calm under pressure',
#   'flexible working',
#   'hard worker',
#   'highly adaptable',
#   'attention to detail',
#   'eager to learn'],
#  ['ableton live',
#   'music production',
#   'logic pro',
#   'serato',
#   'traktor',
#   'sound design',
#   'pro tools',
#   'serato scratch live',
#   'cubase',
#   'electronic music'],
#  ['logic pro',
#   'traktor',
#   'reason',
#   'pro tools',
#   'electronic music',
#   'music production',
#   'sound design',
#   'propellerheads reason',
#   'midi',
#   'cubase'],
#  ['developmental psychology',
#   'social psychology',
#   'psychology',
#   'cognitive psychology',
#   'psychopathology',
#   'forensic psychology',
#   'experimental psychology',
#   'clinical psychology',
#   'dsmiv',
#   'broker price opinion'],
#  ['aboriginal relations',
#   'aboriginal health',
#   'first nations',
#   'indigenous rights',
#   'indigenous education',
#   'community engagement',
#   'stakeholder engagement',
#   'community development',
#   'policy analysis',
#   'policy'],
#  ['aboriginal relations',
#   'aboriginal affairs',
#   'indigenous education',
#   'social determinants of health',
#   'indigenous rights',
#   'public health',
#   'community engagement',
#   'rural health',
#   'first nations',
#   'health promotion'],
#  ['aboriginal affairs',
#   'first nations',
#   'aboriginal health',
#   'indigenous education',
#   'indigenous rights',
#   'community engagement',
#   'community development',
#   'stakeholder engagement',
#   'workshop facilitation',
#   'community investment'],
#  ['below the line advertising',
#   'advertising',
#   'marketing communications',
#   'digital marketing',
#   'brand management',
#   'btl activations',
#   'marketing strategy',
#   'tvc',
#   'ooh',
#   'brand activation'],
#  ['buyer representation',
#   'sellers',
#   'listings',
#   'first time home buyers',
#   'new home sales',
#   'single family homes',
#   'relocation',
#   'council of residential specialists',
#   'epro',
#   'move up buyers'],
#  ['cutting tools',
#   'grinding',
#   'fasteners',
#   'polishing',
#   'refractory',
#   'mirrors',
#   'kilns',
#   'architectural glass',
#   'sandblasting',
#   'industrial supplies'],
#  ['cdo',
#   'mbs',
#   'securitization',
#   'clo',
#   'structured finance',
#   'asset finance',
#   'cmbs',
#   'structured products',
#   'invoice discounting',
#   'fixed income'],
#  ['fluorescence spectroscopy',
#   'ir spectroscopy',
#   'ultrafast spectroscopy',
#   'atomic spectroscopy',
#   'photoluminescence',
#   'spectroscopy',
#   'xray spectroscopy',
#   'physical chemistry',
#   'nmr spectroscopy',
#   'organic solar cells'],
#  ['figurative',
#   'fine art',
#   'contemporary art',
#   'mixed media',
#   'painting',
#   'art',
#   'acrylic',
#   'visual arts',
#   'abstraction',
#   'oil painting'],
#  ['real analysis',
#   'linear algebra',
#   'number theory',
#   'combinatorics',
#   'complex analysis',
#   'discrete mathematics',
#   'differential geometry',
#   'calculus',
#   'multivariable calculus',
#   'mathematics'],
#  ['landscape painting',
#   'acrylic painting',
#   'portrait painting',
#   'pen',
#   'commissioned art',
#   'abstraction',
#   'oil paint',
#   'canvas',
#   'modern art',
#   'studio art'],
#  ['title searches',
#   'chain of title',
#   'mineral rights',
#   'title opinions',
#   'titles',
#   'shale',
#   'division orders',
#   'operating agreements',
#   'deeds',
#   'land administration'],
#  ['modern art',
#   'figurative art',
#   'contemporary art',
#   'public art',
#   'mixed media',
#   'fine art',
#   'galleries',
#   'visual arts',
#   'studio art',
#   'acrylic'],
#  ['publication planning',
#   'medical communications',
#   'scientific communications',
#   'manuscript',
#   'medical writing',
#   'advisory boards',
#   'cme',
#   'manuscript development',
#   'manuscripts',
#   'therapeutic areas'],
#  ['depression',
#   'trauma',
#   'bereavement',
#   'anxiety',
#   'child sexual abuse',
#   'low self esteem',
#   'abuse prevention',
#   'anxiety disorders',
#   'ptsd',
#   'sexual trauma'],
#  ['child abuse prevention',
#   'child sexual abuse',
#   'substance abuse prevention',
#   'violence against women',
#   'sexual violence',
#   'victim services',
#   'abuse',
#   'teen pregnancy prevention',
#   'sexual trauma',
#   'victims of crime'],
#  ['dc',
#   'ap',
#   'xdsl',
#   'ad',
#   'poesia',
#   'aaa',
#   'ducting',
#   'multiplexers',
#   'gaffer',
#   'ahu'],
#  ['dc drives',
#   'servo drives',
#   'plc programming',
#   'plc',
#   'variable frequency drives',
#   'hmi programming',
#   'plc allen bradley',
#   'scada',
#   'automation',
#   'motor drives'],
#  ['spectra',
#   'nielsen',
#   'iri',
#   'shopper marketing',
#   'categorization',
#   'consumer products',
#   'grocery',
#   'trade marketing',
#   'customer marketing',
#   'prospace'],
#  ['inertial navigation',
#   'cadworx plant',
#   'polarity',
#   'cadworx',
#   'microsoft office project',
#   'autocad',
#   'cosmos fea',
#   'virtual design',
#   'medical equipment planning',
#   'labor cost management'],
#  ['higher education',
#   'academic administration',
#   'academic advising',
#   'distance learning',
#   'faculty development',
#   'courses',
#   'student affairs',
#   'higher education administration',
#   'student engagement',
#   'student development'],
#  ['academia',
#   'academic editing',
#   'higher education management',
#   'information seeking',
#   'college',
#   'student services',
#   'academic achievement',
#   'content licensing',
#   'marc',
#   'diplomas'],
#  ['academic journals',
#   'high achiever',
#   'academic tutoring',
#   'academic research',
#   'academic writing',
#   'dissertation editing',
#   'academic support services',
#   'academic english',
#   'character education',
#   'achieve results'],
#  ['higher education',
#   'faculty development',
#   'retaining customers',
#   'academic advising',
#   'higher education administration',
#   'enrollment management',
#   'campus',
#   'student affairs',
#   'distance learning',
#   'academia'],
#  ['student development',
#   'student affairs',
#   'higher education',
#   'admissions',
#   'higher education administration',
#   'student engagement',
#   'academic administration',
#   'enrollment management',
#   'college teaching',
#   'campus'],
#  ['manuscript editing',
#   'academic writing',
#   'editing',
#   'proofreading',
#   'copy editing',
#   'developmental editing',
#   'apa style',
#   'literary',
#   'dissertation editing',
#   'educational publishing'],
#  ['english for specific purposes',
#   'pronunciation',
#   'english grammar',
#   'ielts',
#   'applied linguistics',
#   'toefl',
#   'language testing',
#   'english literature',
#   'tefl',
#   'tesol'],
#  ['academic publishing',
#   'stm',
#   'journals',
#   'academic writing',
#   'open access',
#   'online publishing',
#   'manuscript development',
#   'academic achievement',
#   'textbooks',
#   'manuscript'],
#  ['library science',
#   'information literacy',
#   'library instruction',
#   'electronic resources',
#   'collection development',
#   'digital libraries',
#   'virtual reference',
#   'library research',
#   'library',
#   'library management'],
#  ['textbooks',
#   'educational publishing',
#   'online publishing',
#   'publishing',
#   'ebooks',
#   'journals',
#   'content development',
#   'books',
#   'manuscript development',
#   'publications'],
#  ['academic writing',
#   'academic journals',
#   'academic english',
#   'academic achievement',
#   'academic tutoring',
#   'academic editing',
#   'dissertation editing',
#   'textual analysis',
#   'academic publishing',
#   'research'],
#  ['first year experience',
#   'academic advising',
#   'higher education',
#   'student affairs',
#   'student development',
#   'student leadership training',
#   'community colleges',
#   'student counseling',
#   'student retention',
#   'student engagement'],
#  ['peer tutoring',
#   'online tutoring',
#   'test preparation',
#   'tutoring',
#   'academic writing',
#   'teaching writing',
#   'academic achievement',
#   'academic research',
#   'peer mentoring',
#   'precalculus'],
#  ['theory',
#   'university teaching',
#   'lecturing',
#   'courses',
#   'qualitative research',
#   'higher education',
#   'research design',
#   'academic editing',
#   'academic research',
#   'social sciences'],
#  ['multimeter',
#   'schematic',
#   'electrical troubleshooting',
#   'soldering',
#   'electronics repair',
#   'signal generators',
#   'function generator',
#   'oscilloscope',
#   'test equipment',
#   'wiring diagrams'],
#  ['aat',
#   'accounting',
#   'cima',
#   'financial reporting',
#   'financial accounting',
#   'management accounting',
#   'ifrs',
#   'financial analysis',
#   'vt',
#   'cfa'],
#  ['team center engineering',
#   'bex reporting',
#   'bex analyzer',
#   'xml spy',
#   'durable medical equipment',
#   'accurate record keeping',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['speech therapy',
#   'articulation',
#   'voice disorders',
#   'language disorders',
#   'apraxia',
#   'voice therapy',
#   'dysarthria',
#   'speech',
#   'phonological disorders',
#   'aphasia'],
#  ['acting',
#   'voice acting',
#   'improvisation',
#   'stage combat',
#   'theatre',
#   'dialects',
#   'singing',
#   'drama',
#   'accent reduction',
#   'shakespeare'],
#  ['acceptance testing',
#   'site surveys',
#   'rollout',
#   'edge',
#   'nsn',
#   'bss',
#   'ran',
#   'transmission',
#   'pdh',
#   'gsm'],
#  ['cbt',
#   'mindfulness',
#   'psychotherapy',
#   'mindfulnessbased psychotherapy',
#   'psychology',
#   'psychological assessment',
#   'schema therapy',
#   'mental health',
#   'clinical psychology',
#   'behavioral medicine'],
#  ['acceptance',
#   'rollout',
#   'nsn',
#   'mw',
#   'edge',
#   'pdh',
#   'ran',
#   'node b',
#   'rnc',
#   'bss'],
#  ['personal responsibility',
#   'professional responsibility',
#   'listen',
#   'work without supervision',
#   'follow directions',
#   'thrives on challenges',
#   'well mannered',
#   'sensitivity',
#   'grasp new concepts quickly',
#   'coordinating tasks'],
#  ['eficacia de ventas',
#   'ventas hospitalarias',
#   'lanzamiento de productos',
#   'asuntos normativos',
#   'farmacovigilancia',
#   'market access',
#   'liderazgo de equipos multidisciplinarios',
#   'pharmaceutical industry',
#   'pharmaceutical sales',
#   'sales effectiveness'],
#  ['microsoft excel',
#   'visio',
#   'outlook',
#   'software documentation',
#   'microsoft office',
#   'spreadsheets',
#   'powerpoint',
#   'data entry',
#   'data analysis',
#   'ms access'],
#  ['cctv',
#   'alarm systems',
#   'video over ip',
#   'video analytics',
#   'ip cameras',
#   'intrusion',
#   'burglar alarm',
#   'biometrics',
#   'alarms',
#   'electronic security'],
#  ['physical access control',
#   'identity management',
#   'ip cctv',
#   'iam',
#   'rbac',
#   'identity federation',
#   'tivoli access manager',
#   'access control',
#   'physical security surveys',
#   'tivoli identity manager'],
#  ['microsoft excel',
#   'database queries',
#   'managing database',
#   'vba',
#   'ms excel pivot tables',
#   'relational databases',
#   'monarch pro',
#   'access',
#   'query writing',
#   'database design'],
#  ['netscaler',
#   'citrix',
#   'citrix metaframe',
#   'application virtualization',
#   'xenserver',
#   'xendesktop',
#   'xenapp',
#   'citrix certified administrator',
#   'xen',
#   'vdi'],
#  ['acl',
#   'nat',
#   'vtp',
#   'etherchannel',
#   'cisa',
#   'itgc',
#   'vlan',
#   'it audit',
#   'eigrp',
#   'coso'],
#  ['siteminder',
#   'identity federation',
#   'rbac',
#   'federation',
#   'identity management',
#   'sso',
#   'directory services',
#   'iam',
#   'idm',
#   'saml'],
#  ['fttx',
#   'gpon',
#   'dslam',
#   'msan',
#   'telecommunications',
#   'ftth',
#   'sdh',
#   'ip',
#   'transmission',
#   'dwdm'],
#  ['wireless lan controller',
#   'cisco access points',
#   'wireless networking',
#   'switches',
#   'routers',
#   'wireless access',
#   'patch panels',
#   'wireless routers',
#   'vlan',
#   'tcpandip'],
#  ['web standards',
#   'usability',
#   'wcag',
#   'information architecture',
#   'card sorting',
#   'user experience',
#   'w3c',
#   'wire framing',
#   'section 508',
#   'user interface design'],
#  ['fashion',
#   'handbags',
#   'bags',
#   'apparel',
#   'womenswear',
#   'fashion design',
#   'leather',
#   'kidswear',
#   'accessory design',
#   'shoes'],
#  ['window coverings',
#   'draperies',
#   'window treatments',
#   'bedding',
#   'furnishings',
#   'blinds',
#   'model homes',
#   'floor plans',
#   'color schemes',
#   'area rugs'],
#  ['fashion design',
#   'flat sketching',
#   'flats',
#   'sewing',
#   'mood boards',
#   'fashion',
#   'fashion illustration',
#   'patterns',
#   'garment construction',
#   'trend research'],
#  ['ingegneria',
#   'strutture in acciaio',
#   'calcestruzzo',
#   'ingegneria strutturale',
#   'analisi strutturale',
#   'ingegneria dei progetti',
#   'ingegneria civile',
#   'materiali',
#   'fabbriche',
#   'saldatura'],
#  ['cafeteria plans',
#   'insurance',
#   'whole life',
#   'accident insurance',
#   'health savings accounts',
#   'disability insurance',
#   'term life insurance',
#   'critical illness',
#   'supplemental insurance',
#   'voluntary employee benefits'],
#  ['third party liability',
#   'accident management',
#   'credit hire',
#   'claims handling',
#   'claims investigations',
#   'automobile accidents',
#   'claims resolution',
#   'accident',
#   'fraud claims',
#   'automobile liability'],
#  ['cafeteria plans',
#   'voluntary employee benefits',
#   'life insurance',
#   'vision insurance',
#   'disability insurance',
#   'health insurance',
#   'critical illness',
#   'term life insurance',
#   'whole life',
#   'flexible spending accounts'],
#  ['behavior based safety',
#   'hazard analysis',
#   'hazard recognition',
#   'occupational health',
#   'safety management systems',
#   'safety auditing',
#   'incident investigation',
#   'industrial safety',
#   'hazard identification',
#   'safety training'],
#  ['accident claims',
#   'credit hire',
#   'accident investigation',
#   'contract hire',
#   'fleet leasing',
#   'collision',
#   'fleet management',
#   'paintless dent repair',
#   'fleet operations',
#   'fleet services'],
#  ['traffic enforcement',
#   'criminal investigations',
#   'police',
#   'patrol',
#   'evidence',
#   'field training officer',
#   'evidence collection',
#   'criminal justice',
#   'investigation',
#   'crime scene'],
#  ['rentas fijas',
#   'mercados financieros',
#   'mercado de capitales',
#   'derivados',
#   'inversiones',
#   'finanzas corporativas',
#   'banca',
#   'banca privada',
#   'comercio',
#   'finanzas'],
#  ['control de cambios',
#   'poe',
#   'asuntos normativos',
#   'control de calidad',
#   'productos sanitarios',
#   'capa',
#   'mejora continua',
#   'gmp',
#   'liderazgo de equipos multidisciplinarios',
#   'mejora de procesos'],
#  ['formation',
#   'conseil',
#   'animation datelier',
#   'coaching professionnel',
#   'animation de formation',
#   'recrutement',
#   'offre de formation',
#   'relation daide',
#   'ressources humaines',
#   'gestion de projet'],
#  ['pianist',
#   'piano',
#   'choral',
#   'music education',
#   'classical',
#   'music history',
#   'music theory',
#   'organ',
#   'choral conducting',
#   'ensemble'],
#  ['accompaniment',
#   'piano',
#   'pianist',
#   'piano performance',
#   'music education',
#   'music theory',
#   'music',
#   'choral',
#   'classical',
#   'music instruction'],
#  ['piano',
#   'music',
#   'mandolin',
#   'recorder',
#   'music theory',
#   'ukulele',
#   'guitar',
#   'singing',
#   'composition',
#   'music education'],
#  ['bank',
#   'sage line 100',
#   'marketing integrato',
#   'account administration',
#   'custom',
#   'onderzoek',
#   'expenditure control',
#   'negotiating fees',
#   'numeric',
#   'cisco certified network associate'],
#  ['marketing campaigns',
#   'sales administration',
#   'remote user support',
#   'loans administration',
#   'owa',
#   'exchange activesync',
#   'desktop application support',
#   'file sharing',
#   'queue management',
#   'nostro reconciliation'],
#  ['workamajig',
#   'account management',
#   'account direction',
#   'trade show coordination',
#   'advertising',
#   'sales coordination',
#   'media placement',
#   'targeted advertising',
#   'integrated media',
#   'print media sales'],
#  ['digital marketing',
#   'digital strategy',
#   'yellow pages',
#   'integrated marketing',
#   'advertising',
#   'ooh',
#   'integrated media',
#   'media sales',
#   'print media sales',
#   'marketing communications'],
#  ['account management experience',
#   'national account experience',
#   'account management',
#   'account servicing',
#   'loan officers',
#   'sales',
#   'broadcast media sales',
#   'account direction',
#   'yellow pages',
#   'marketing'],
#  ['new account opening',
#   'opening new accounts',
#   'wire transfers',
#   'large account sales',
#   'customer service',
#   'partnership tax returns',
#   'trust taxation',
#   'bank reconciliations',
#   'territory analysis',
#   'branch operation'],
#  ['sales process',
#   'direct sales',
#   'cold calling',
#   'b2b',
#   'major accounts',
#   'sales management',
#   'new business development',
#   'solution selling',
#   'sales operations',
#   'sales'],
#  ['account executives',
#   'enterprise account management',
#   'account management',
#   'business to business relationship building',
#   'clevel relationships',
#   'executivelevel relationships',
#   'exceeding quotas',
#   'territory penetration',
#   'territory account management',
#   'operational oversight'],
#  ['product manager',
#   'project manager',
#   'recruiter',
#   'grande distribution',
#   'business consultant',
#   'general manager',
#   'production manager',
#   'field sales',
#   'event coordinator',
#   'sales representative'],
#  ['account management',
#   'qualifying prospects',
#   'creative briefs',
#   'solution selling',
#   'pipeline management',
#   'strategic account development',
#   'strategic sales',
#   'brand positioning strategies',
#   'advertising',
#   'global account development'],
#  ['general ledger',
#   'journal entries',
#   'accruals',
#   'accounts payable',
#   'accounting',
#   'fixed assets',
#   'accounts receivable',
#   'bank reconciliation',
#   'financial statements',
#   'reconciliations'],
#  ['customer retention',
#   'account management',
#   'consultative selling',
#   'revenue growth',
#   'large account sales',
#   'sales pipeline management',
#   'territory planning',
#   'economic growth',
#   'new business development',
#   'national account sales'],
#  ['strategic sales plans',
#   'strategic sales',
#   'strategic sales initiatives',
#   'sales strategy',
#   'sales management',
#   'sales',
#   'territory account management',
#   'spin sales training',
#   'hcm',
#   'presidents club'],
#  ['account executives',
#   'business to business relationship building',
#   'account direction',
#   'account maintenance',
#   'new account opening',
#   'media placement',
#   'advertising',
#   'digital marketing',
#   'district sales management',
#   'client visits'],
#  ['accountable',
#   'multiunit management',
#   'district management',
#   'multiunit retail management',
#   'big box',
#   'associate development',
#   'new store development',
#   'shrink control',
#   'integrity',
#   'multiunit'],
#  ['accountability',
#   'respectful',
#   'dependable',
#   'passionate',
#   'organized',
#   'trustworthy',
#   'responsible',
#   'professional',
#   'decisive',
#   'logical thinking'],
#  ['population health',
#   'healthcare',
#   'physician alignment',
#   'healthcare consulting',
#   'healthcare information technology',
#   'managed care',
#   'healthcare industry',
#   'healthcare management',
#   'provider network development',
#   'physician network development'],
#  ['taxation',
#   'management accounts',
#   'idea',
#   'administratie',
#   'limited companies',
#   'exact online',
#   'capital gains tax',
#   'trusteeship',
#   'accounting',
#   'financial projections'],
#  ['auditor',
#   'limited companies',
#   'office manager',
#   'attorney',
#   'estimator',
#   'controller',
#   'mba finance',
#   'coordinator',
#   'partnership accounting',
#   'coordinate'],
#  ['accounting',
#   'income tax',
#   'tax',
#   'tax returns',
#   'corporate tax',
#   'year end accounts',
#   'sales tax',
#   'vat',
#   'partnership taxation',
#   'business tax'],
#  ['gaap',
#   'financial reporting',
#   'general ledger',
#   'financial statements',
#   'financial accounting',
#   'internal controls',
#   'account reconciliation',
#   'tax',
#   'fixed assets',
#   'auditing'],
#  ['accounting software',
#   'ledger',
#   'cash receipts',
#   'accounting system',
#   'year end accounts',
#   'accounting',
#   'bank reconciliation',
#   'depreciation',
#   'yearend close',
#   'balance'],
#  ['small business tax',
#   'small business financial management',
#   'multistate tax returns',
#   'business tax planning',
#   'tax preparation',
#   'marketing for small business',
#   'personal income tax returns',
#   'fullcharge bookkeeping',
#   'quickbooks',
#   'ultratax'],
#  ['frx',
#   'monthly close',
#   'fixed asset management',
#   'accounting system',
#   'monthly closing',
#   'international accounting',
#   'inventory valuation',
#   'consolidated financial statements',
#   'monthly close process',
#   'yearend close'],
#  ['accounting',
#   'technical accounting research',
#   'fasb',
#   'gaap',
#   'financial reporting',
#   'us gaap',
#   'technical accounting',
#   'auditing',
#   'single audit',
#   'sec filings'],
#  ['accounting applications',
#   'payroll software',
#   'tax software',
#   'ibm rational system architect',
#   'accounting',
#   'bank reconciliations',
#   'small business it solutions',
#   'accounts payable',
#   'visual paradigm',
#   'financial accounting'],
#  ['statutory audit',
#   'direct tax',
#   'tds',
#   'auditing',
#   'indirect taxation',
#   'statutory accounting',
#   'financial accounting',
#   'accounting',
#   'tally erp',
#   'income tax'],
#  ['accounting applications',
#   'accounting',
#   'accounting management',
#   'ledger',
#   'balance sheet',
#   'monthly close',
#   'financial reporting',
#   'yearend close',
#   'monthly closing',
#   'year end accounts'],
#  ['taxation',
#   'business advice',
#   'credit control',
#   'management information system',
#   'costing',
#   'project financing',
#   'service tax',
#   'vat returns',
#   'management accounts',
#   'tally'],
#  ['accounts receivable',
#   'account reconciliation',
#   'general ledger',
#   'journal entries',
#   'bank reconciliation',
#   'accruals',
#   'fixed assets',
#   'accounting',
#   'balance',
#   'quickbooks'],
#  ['invoice processing',
#   'general ledger administration',
#   'cash receipts',
#   'petty cash',
#   'bank reconciliation',
#   'bank statements',
#   'payroll',
#   'quickbooks',
#   'inventory accounting',
#   'intercompany accounts'],
#  ['accounts payable',
#   'account reconciliation',
#   'general ledger',
#   'journal entries',
#   'bank reconciliation',
#   'accruals',
#   'cash receipts',
#   'invoicing',
#   'balance',
#   'accounting'],
#  ['exact',
#   'exact online',
#   'exact globe',
#   'caseware',
#   'duits',
#   'administratie',
#   'basware',
#   'nederlands',
#   'engels',
#   'microsoft excel'],
#  ['simply accounting',
#   'mas 90',
#   'yearend close',
#   'accounts payable',
#   'accounts receivable',
#   'bank reconciliation',
#   'cash receipts',
#   'account reconciliation',
#   'great plains software',
#   'accounting'],
#  ['campusvue',
#   'retaining customers',
#   'campus',
#   'quality improvement',
#   'enrollment management',
#   'academic administration',
#   'ncqa',
#   'student financial aid',
#   'jcaho',
#   'healthcare consulting'],
#  ['first time home buyers',
#   'sellers',
#   'buyer education',
#   'buyer representation',
#   'real estate',
#   'buyer broker',
#   'single family homes',
#   'buyers',
#   'first time sellers',
#   'seller representation'],
#  ['real estate',
#   'buyer representation',
#   'sellers',
#   'single family homes',
#   'first time home buyers',
#   'investment properties',
#   'condos',
#   'new home sales',
#   'short sales',
#   'residential homes'],
#  ['account reconciliation',
#   'journal entries',
#   'general ledger',
#   'fixed assets',
#   'prepayment',
#   'depreciation',
#   'yearend close',
#   'accounts payable',
#   'accounting',
#   'bank reconciliation'],
#  ['caisse',
#   'facturation',
#   'archivage',
#   'relationnel',
#   'conseil',
#   'polyvalence',
#   'gestion administrative',
#   'tourisme',
#   'assistance administrative',
#   'vente'],
#  ['flexibel',
#   'zelfstandig',
#   'klantgericht',
#   'stressbestendig',
#   'collegiaal',
#   'integer',
#   'betrouwbaar',
#   'verantwoordelijk',
#   'resultaatgericht',
#   'proactief'],
#  ['attention to detail',
#   'attention to details',
#   'meeting deadlines',
#   'ability to work under pressure',
#   'prioritizing',
#   'detail orientation',
#   'loyalty',
#   'leading teams',
#   'correspondence',
#   'responsibility'],
#  ['productive',
#   'stress resistant',
#   'independent',
#   'ambitious',
#   'honest',
#   'structured',
#   'efficient',
#   'precise',
#   'detailed',
#   'decisive'],
#  ['accurate record keeping',
#   'online data entry',
#   'multiline phone',
#   'copying',
#   'ten key',
#   'general office skills',
#   'postage meter',
#   'telephone reception',
#   'clerical work',
#   'filing'],
#  ['accurate data entry',
#   'high level of accuracy',
#   'close attention to detail',
#   'filing',
#   'work independently with minimal supervision',
#   'customer service',
#   'handle confidential information',
#   'confidential documents',
#   'work in a fast paced environment',
#   'data entry'],
#  ['agile methodologies',
#   'jira',
#   'java',
#   'c',
#   'clearcase',
#   'xml',
#   'eclipse',
#   'ant',
#   'cruisecontrol',
#   'jenkins'],
#  ['pacer',
#   'lexisnexis',
#   'imanage',
#   'fdcpa',
#   'skip tracing',
#   'efiling',
#   'dunn and bradstreet',
#   'factiva',
#   'client profiles',
#   'westlaw'],
#  ['ivr',
#   'cti',
#   'avaya',
#   'telephony',
#   'contact centers',
#   'call logging',
#   'voice mail',
#   'unified messaging',
#   'voip',
#   'telecommunications'],
#  ['fwsm',
#   'asa',
#   'nexus 7k',
#   'corba',
#   'pix',
#   'nexus',
#   'load balancing',
#   'cisco nexus',
#   'f5 bigip',
#   'boost'],
#  ['personal training',
#   'trx certified',
#   'fitness training',
#   'strength training',
#   'weight training',
#   'fitness',
#   'trx suspension training',
#   'acsm health fitness',
#   'special populations',
#   'group exercise instruction'],
#  ['estructuras de acero',
#   'soldaduras',
#   'materiales',
#   'metalurgia',
#   'puentes',
#   'ensayos no destructivos',
#   'mejora continua',
#   'planeamiento de proyectos',
#   'calderas',
#   'manufactura'],
#  ['microsoft excel',
#   'powerpoint',
#   'microsoft word',
#   'microsoft office',
#   'phc',
#   'white belt',
#   'excels',
#   'internet',
#   'frontpage',
#   'microsiga'],
#  ['venda de produtos hospitalares',
#   'planejamento de mercado',
#   'cardiologia',
#   'oncologia',
#   'endocrinologia',
#   'dermatologia',
#   'neurologia',
#   'planejamento empresarial',
#   'reumatologia',
#   'market access'],
#  ['electronic payments',
#   'remote deposit capture',
#   'merchant services',
#   'debit cards',
#   'payments',
#   'gift cards',
#   'payment card processing',
#   'epayments',
#   'payment systems',
#   'payment gateways'],
#  ['logistique',
#   'approvisionnement',
#   'negociation',
#   'gestion de stock',
#   'gestion',
#   'vente',
#   'grande distribution',
#   'gestion dentreprise',
#   'gestion de production',
#   'luxe'],
#  ['sourcing mondial',
#   'gestion des fournitures',
#   'approvisionnement',
#   'logistique',
#   'tarification',
#   'gestion des stocks',
#   'gestion des achats',
#   'sales manager',
#   'optimisation de la chaine logistique',
#   'conception de produit'],
#  ['high achiever',
#   'objectivity',
#   'achieving results',
#   'maximizer',
#   'freight auditing',
#   'exceed sales goals',
#   'client focus',
#   'result oriented',
#   'quota achievement',
#   'delivering results'],
#  ['learner',
#   'relator',
#   'maximizer',
#   'activator',
#   'individualization',
#   'includer',
#   'competition',
#   'restorative',
#   'responsibility',
#   'developer'],
#  ['driven by results',
#   'drive results',
#   'high achiever',
#   'quota achievement',
#   'exceeding quotas',
#   'exceed sales goals',
#   'goal analysis',
#   'exceeding customer expectations',
#   'endocrinologia',
#   'team motivation'],
#  ['delivering results',
#   'achieving targets',
#   'high achiever',
#   'achieve results',
#   'result oriented',
#   'focus on results',
#   'observant',
#   'targets',
#   'influential',
#   'driving revenue'],
#  ['sales targets',
#   'target oriented',
#   'team motivator',
#   'achieving results',
#   'persuasion skills',
#   'large account sales',
#   'action planning',
#   'flexible working',
#   'closing skills',
#   'client relationship building'],
#  ['aisc',
#   'reinforced concrete',
#   'ibc',
#   'structural engineering',
#   'seismic design',
#   'structural analysis',
#   'steel design',
#   'steel structures',
#   'concrete',
#   'etabs'],
#  ['sound forge',
#   'fruity loops',
#   'sony vegas',
#   'cakewalk sonar',
#   'cubase',
#   'wavelab',
#   'propellerheads reason',
#   'serato scratch live',
#   'fl studio',
#   'sony vegas video'],
#  ['hydraulic fracturing',
#   'well stimulation',
#   'stimulation',
#   'fracture',
#   'oilfield',
#   'tubing',
#   'frac',
#   'completion',
#   'completions',
#   'cement'],
#  ['access lists',
#   'idea',
#   'teammate',
#   'itgc',
#   'it audit',
#   'internal audit',
#   'segregation of duties',
#   'coso',
#   'nat',
#   'it risk'],
#  ['bls',
#   'pals',
#   'tncc',
#   'critical care',
#   'enpc',
#   'ccrn',
#   'acute care',
#   'icu',
#   'pepp',
#   'nursing'],
#  ['bls certified',
#   'cpr certified',
#   'acls',
#   'bls',
#   'nursing',
#   'iv certified',
#   'healthcare',
#   'patient safety',
#   'patient education',
#   'telemetry'],
#  ['bls instruction',
#   'cpr instruction',
#   'acls',
#   'bls',
#   'paramedic',
#   'critical care',
#   'pals',
#   'phtls',
#   'healthcare',
#   'ems education'],
#  ['bls instructor',
#   'cphq',
#   'acls',
#   'pals',
#   'bls',
#   'cpr instructor',
#   'critical care',
#   'paramedic',
#   'phtls',
#   'emergency medicine'],
#  ['microdermabrasion',
#   'skin care',
#   'skin',
#   'rosacea',
#   'chemical peels',
#   'skin care products',
#   'hyperpigmentation',
#   'acne treatment',
#   'sensitive skin',
#   'spa'],
#  ['rosacea',
#   'hyperpigmentation',
#   'sensitive skin',
#   'chemical peels',
#   'skin resurfacing',
#   'microdermabrasion',
#   'sun damage',
#   'acne',
#   'skin care',
#   'microcurrent'],
#  ['simple comptable',
#   'sage 50',
#   'microsoft excel',
#   'comptes fournisseurs',
#   'facturation',
#   'caseware',
#   'tenue comptable',
#   'microsoft office',
#   'paie',
#   'accpac'],
#  ['document management',
#   'edms',
#   'eroom',
#   'document control',
#   'projectwise',
#   'construction',
#   'project control',
#   'proarc',
#   'infoworks',
#   'documentum'],
#  ['bemestar',
#   'treinamento em bemestar',
#   'clinical nutrition',
#   'treinamento individual',
#   'hospitais',
#   'setor de alimentos',
#   'nutrition education',
#   'nutrition',
#   'human nutrition',
#   'nutritional counseling'],
#  ['architectural acoustics',
#   'noise control',
#   'vibration control',
#   'acoustics',
#   'room acoustics',
#   'psychoacoustics',
#   'environmental noise',
#   'acoustic measurement',
#   'acoustic modeling',
#   'noise reduction'],
#  ['electric guitar',
#   'rhythm guitar',
#   'lead guitar',
#   'bass guitar',
#   'guitarist',
#   'guitar',
#   'mandolin',
#   'classical guitar',
#   'blues guitar',
#   'jazz guitar'],
#  ['acoustic modeling',
#   'architectural acoustics',
#   'acoustics',
#   'environmental noise',
#   'noise control',
#   'noise reduction',
#   'vibration isolation',
#   'vibration control',
#   'acoustic',
#   'psychoacoustics'],
#  ['acoustic measurement',
#   'architectural acoustics',
#   'environmental noise',
#   'acoustics',
#   'noise control',
#   'noise reduction',
#   'vibration isolation',
#   'vibration control',
#   'acoustic',
#   'room acoustics'],
#  ['suspended ceilings',
#   'drywall',
#   'ceilings',
#   'steel framing',
#   'framing',
#   'plastering',
#   'stucco',
#   'insulation',
#   'architectural acoustics',
#   'carpentry'],
#  ['room acoustics',
#   'architectural acoustics',
#   'psychoacoustics',
#   'noise control',
#   'acoustic measurement',
#   'acoustic modeling',
#   'environmental noise',
#   'vibration control',
#   'acoustic',
#   'noise reduction'],
#  ['traitement du signal',
#   'sonorisation',
#   'vibration',
#   'son',
#   'thermodynamique',
#   'capteurs',
#   'transfert thermique',
#   'design sonore',
#   'physique',
#   'automatique'],
#  ['ingegneria ambientale',
#   'ambientalismo',
#   'valutazione di impatto ambientale',
#   'consulenza ambientale',
#   'sistemi di gestione ambientale',
#   'ingegneria',
#   'gestione dei rifiuti',
#   'ingegneria geotecnica',
#   'ingegneria civile',
#   'scienze ambientali'],
#  ['traumatic brain injury',
#   'brain injury',
#   'cognitive rehabilitation',
#   'neurorehabilitation',
#   'stroke rehabilitation',
#   'neurological disorders',
#   'spinal cord injury',
#   'rehabilitation',
#   'cognition',
#   'dysarthria'],
#  ['debit cards',
#   'payment systems',
#   'electronic payments',
#   'payment card processing',
#   'cards',
#   'payments',
#   'credit cards',
#   'mobile payments',
#   'epayments',
#   'payment gateways'],
#  ['financement',
#   'fusion',
#   'industrie',
#   'requirements',
#   'juridique',
#   'international experience',
#   'financing',
#   'production control',
#   'cfo',
#   'leadership experience'],
#  ['business valuation',
#   'manda due diligence',
#   'mergers',
#   'acquisition integration',
#   'mergers and acquisitions',
#   'board reporting',
#   'financial modeling',
#   'due diligence',
#   'debt structuring',
#   'strategic analysis'],
#  ['ressources humaines',
#   'recrutement',
#   'gestion des talents',
#   'recrutement technique',
#   'recherche de dirigeants',
#   'gestion des performances',
#   'consulting rh',
#   'planification de successions',
#   'marque employeur',
#   'entretiens'],
#  ['mergers and acquisitions',
#   'divestitures',
#   'mergers',
#   'corporate development',
#   'restructuring',
#   'market entry',
#   'strategy',
#   'post merger integration',
#   'due diligence',
#   'executive management'],
#  ['disposition',
#   'due diligence',
#   'real estate private equity',
#   'divestitures',
#   'investment sales',
#   'dispositions',
#   'real estate economics',
#   'location intelligence',
#   'lease negotiations',
#   'tenant representation'],
#  ['risorse umane',
#   'gestione dei talenti',
#   'selezione del personale tecnico',
#   'ricerca dirigenti',
#   'consulenza hr',
#   'relazioni con i dipendenti',
#   'gestione delle performance',
#   'recruiting',
#   'sviluppo organizzativo',
#   'ricerca e selezione del personale'],
#  ['recruiting strategico',
#   'trattative',
#   'gestione fornitori',
#   'gestione supply chain',
#   'approvvigionamento',
#   'logistica',
#   'determinazione dei prezzi',
#   'gestione vendite',
#   'magazzino',
#   'sviluppo di prodotto'],
#  ['mergers',
#   'reverse mergers',
#   'transaction services',
#   'mergers and acquisitions',
#   'general commercial agreements',
#   'shareholder agreements',
#   'spinoffs',
#   'property disposition',
#   'microsoft programs',
#   'distressed manda'],
#  ['sellers',
#   'buyer representation',
#   'single family homes',
#   'first time home buyers',
#   'listings',
#   'new home sales',
#   'relocation',
#   'relocation buyers',
#   'new homes',
#   'listing homes'],
#  ['illustrator',
#   'indesign',
#   'photoshop',
#   'adobe acrobat',
#   'dreamweaver',
#   'fireworks',
#   'enfocus pitstop',
#   'quarkxpress',
#   'freehand',
#   'flash'],
#  ['circus',
#   'circus arts',
#   'aerial silks',
#   'tumbling',
#   'gymnastics',
#   'trapeze',
#   'lyrical',
#   'choreography',
#   'stunts',
#   'dance'],
#  ['active directory',
#   'windows server',
#   'microsoft exchange',
#   'gfi',
#   'eset',
#   'acronis true image',
#   'norton ghost',
#   'vmware',
#   'backup exec',
#   'symantec endpoint protection'],
#  ['active directory',
#   'norton ghost',
#   'windows server',
#   'ghost imaging',
#   'windows 7',
#   'malwarebytes',
#   'acronis',
#   'microsoft exchange',
#   'teamviewer',
#   'symantec endpoint protection'],
#  ['mixed media',
#   'watercolor',
#   'figurative art',
#   'painting',
#   'fine art',
#   'oil painting',
#   'visual arts',
#   'abstraction',
#   'contemporary art',
#   'collage'],
#  ['abstract paintings',
#   'landscape painting',
#   'portrait painting',
#   'oil painting',
#   'commissioned art',
#   'oil paint',
#   'oil pastel',
#   'pen',
#   'watercolor',
#   'charcoal art'],
#  ['casino',
#   'gaming industry',
#   'casino gaming',
#   'baccarat',
#   'vip',
#   'indian gaming',
#   'tribal gaming',
#   'gaming',
#   'blackjack',
#   'roulette'],
#  ['personal training',
#   'exercise prescription',
#   'exercise physiology',
#   'fitness',
#   'group exercise instruction',
#   'fitness training',
#   'special populations',
#   'medical exercise',
#   'strength training',
#   'exercise instruction'],
#  ['goldmine',
#   'sat',
#   'sage crm',
#   'gmat',
#   'sales logix',
#   'act crm',
#   'constant contact',
#   'sage 200',
#   'ipt',
#   'sugarcrm'],
#  ['sage crm',
#   'sales logix',
#   'crm integration',
#   'goldmine',
#   'crm databases',
#   'salesforce crm',
#   'act',
#   'microsoft crm',
#   'crm',
#   'maximizer'],
#  ['suspicious activity reporting',
#   'anti money laundering',
#   'ofac',
#   'usa patriot act',
#   'bank secrecy act',
#   'aml',
#   'kyc',
#   'cams',
#   'cdd',
#   'pep'],
#  ['dialects',
#   'stage combat',
#   'plays',
#   'shakespeare',
#   'drama',
#   'improvisation',
#   'theatre',
#   'teaching acting',
#   'comedy',
#   'stage'],
#  ['acting',
#   'film acting',
#   'theatre',
#   'drama',
#   'plays',
#   'acting training',
#   'performing arts',
#   'voice acting',
#   'shakespeare',
#   'stage'],
#  ['teaching acting',
#   'acting',
#   'acting coach',
#   'theatre',
#   'voice acting',
#   'stage direction',
#   'character actor',
#   'stage combat',
#   'shakespeare',
#   'physical comedy'],
#  ['motion pictures',
#   'stunts',
#   'dialogue',
#   'action planning',
#   'adventure',
#   'story structure',
#   'science fiction',
#   'script',
#   'preproduction',
#   'challenges'],
#  ['executive development',
#   'executive coaching',
#   'management development',
#   'culture change',
#   'mbti',
#   'emotional intelligence',
#   'workshop facilitation',
#   'leadership development',
#   'organizational development',
#   'personal development'],
#  ['drive for results',
#   'peer relationships',
#   'dealing with ambiguity',
#   'itunes',
#   'apple certified technician',
#   'ipod',
#   'ilife',
#   'iphoto',
#   'drive for success',
#   'interpersonal savvy'],
#  ['action plan development',
#   'planogram development',
#   'pareto charts',
#   'constructive feedback',
#   'mtbf',
#   'cross merchandising',
#   'caseload management',
#   'organizational vision',
#   'welfaretowork',
#   'gemba'],
#  ['action plan creation',
#   'personal development plans',
#   'federal and state regulations',
#   'corrective actions',
#   'multidisciplinary teams',
#   'safeguarding adults',
#   'disciplinary action',
#   'schedule writing',
#   'foundries',
#   'antisocial behaviour'],
#  ['plannning',
#   'stress tolerance',
#   'self motivation',
#   'selfawareness',
#   'drive',
#   'verbal communication',
#   'numeracy',
#   'commercial awareness',
#   'commitment',
#   'customer orientation'],
#  ['participatory action research',
#   'appreciative inquiry',
#   'qualitative research',
#   'action learning',
#   'educational research',
#   'teaching',
#   'participatory approaches',
#   'participatory planning',
#   'curriculum design',
#   'business education'],
#  ['sporting goods',
#   'footwear',
#   'sportswear',
#   'snowboarding',
#   'skateboarding',
#   'sports marketing',
#   'athlete marketing',
#   'apparel',
#   'bicycle',
#   'sporting goods industry'],
#  ['puremvc',
#   'mxml',
#   'flash builder',
#   'flash',
#   'adobe air',
#   'cairngorm',
#   'flash games',
#   'flex',
#   'flashdevelop',
#   'flex builder'],
#  ['actionscript',
#   'javascript',
#   'flash',
#   'css',
#   'php',
#   'jquery',
#   'flashdevelop',
#   'html 5',
#   'flex',
#   'puremvc'],
#  ['actionscript',
#   'javascript',
#   'flash',
#   'css',
#   'jquery',
#   'php',
#   'flash builder',
#   'mxml',
#   'adobe air',
#   'css3'],
#  ['facilidad de palabra',
#   'trabajo en equipo',
#   'responsable',
#   'proactivo',
#   'proactiva',
#   'toma de decisiones',
#   'honestidad',
#   'facilidad de aprendizaje',
#   'honesta',
#   'trabajo bajo presion'],
#  ['adaptabilidad',
#   'trabajo en equipo',
#   'confianza',
#   'proactivo',
#   'responsable',
#   'perseverante',
#   'proactiva',
#   'asertividad',
#   'creatividad',
#   'responsabilidad'],
#  ['wastewater treatment',
#   'water treatment',
#   'anaerobic digestion',
#   'industrial wastewater',
#   'wastewater treatment design',
#   'potable water treatment',
#   'recycled water',
#   'water',
#   'waste water treatment plants',
#   'industrial water treatment'],
#  ['below the line advertising',
#   'brand activation',
#   'marketing activation',
#   'btl activations',
#   'brand management',
#   'integrated marketing',
#   'marketing communications',
#   'relationship marketing',
#   'media planning',
#   'advertising'],
#  ['diversified technique',
#   'flexion distraction',
#   'maximizer',
#   'individualization',
#   'achiever',
#   'includer',
#   'learner',
#   'relator',
#   'extremity adjusting',
#   'chiropractic'],
#  ['ambitious',
#   'hard worker',
#   'courteous',
#   'smart',
#   'responsible',
#   'windows 2008',
#   'assertive',
#   'energetic',
#   'attentive',
#   'accurate'],
#  ['group policy',
#   'windows server',
#   'microsoft exchange',
#   'wsus',
#   'blackberry enterprise server',
#   'sccm',
#   'dhcp',
#   'servers',
#   'dns',
#   'vmware'],
#  ['windows server',
#   'microsoft exchange',
#   'windows 7',
#   'exchange 2010and2007and2003',
#   'windows 7 migration',
#   'server 20002008',
#   'active directory',
# ...
#   'pll',
#   'semiconductors',
#   'power management',
#   'analog circuit design',
#   'cmos',
#   'asic',
#   'spectre'],
#  ['analog design',
#   'spectre',
#   'analog',
#   'pll',
#   'circuit design',
#   'mixed signal',
#   'bicmos',
#   'mixedsignal ic design',
#   'cmos',
#   'integrated circuit design'],
#  ['digital electronics',
#   'digital circuit design',
#   'analog signal processing',
#   'analog circuit design',
#   'rf circuits',
#   'electronics',
#   'oscilloscope',
#   'microcontrollers',
#   'mixedsignal ic design',
#   'matlab'],
#  ['analog circuit design',
#   'analog',
#   'mixed signal',
#   'circuit design',
#   'ic',
#   'cmos',
#   'spectre',
#   'pll',
#   'integrated circuit design',
#   'hardware design'],
#  ['digital photography',
#   'darkroom',
#   'photography',
#   'photoshop',
#   'medium format',
#   'portrait photography',
#   'lightroom',
#   'hasselblad',
#   'fine art photography',
#   'photographic printing'],
#  ['digital recording',
#   'live recording',
#   'studio recording',
#   'audio engineering',
#   'pro tools',
#   'microphone placement',
#   'music production',
#   'recording studio',
#   'audio post production',
#   'monitor mixing'],
#  ['analog recording',
#   'digital signal processing',
#   'analog circuit design',
#   'analog circuits',
#   'digital electronics',
#   'digital signal processors',
#   'microphone placement',
#   'digital circuit design',
#   'mixedsignal ic design',
#   'amplifiers'],
#  ['semiconducteur',
#   'semiconducteurs',
#   'analog',
#   'analog circuit design',
#   'asic',
#   'mixed signal',
#   'electronics',
#   'bicmos',
#   'digital electronics',
#   'microelectronics'],
#  ['ecoute',
#   'formidling',
#   'rigueur',
#   'autonomie',
#   'projektledelse',
#   'organisation',
#   'dynamisme',
#   'relationnel',
#   'gestion',
#   'onderzoek'],
#  ['cahier des charges fonctionnel',
#   'gestion de projet',
#   'analyse fonctionnelle',
#   'appel doffres',
#   'relations clients',
#   'animation datelier',
#   'amoa',
#   'accompagnement',
#   'gestion des litiges',
#   'ecoute'],
#  ['amdec',
#   'manufacture',
#   'gestion de la maintenance',
#   'lean manufacturing',
#   'usine',
#   'gestion de projet',
#   'conception de produit',
#   'analyse des risques',
#   'six sigma',
#   'kaizen'],
#  ['gestion de projet logiciel',
#   'analyste commercial',
#   'gestion de projet',
#   'processus commerciaux',
#   'architecture de solution',
#   'architecture dentreprise',
#   'analyse fonctionnelle',
#   'gestion cycle de vie produit',
#   'conception de logiciels',
#   'sql'],
#  ['politique publique',
#   'relations internationales',
#   'politique',
#   'politiques',
#   'sciences politiques',
#   'gouvernement',
#   'organisation non gouvernementale',
#   'droits de lhomme',
#   'diplomatie',
#   'recherche'],
#  ['gestion des rendements',
#   'tourisme',
#   'restauration et boissons',
#   'loisirs',
#   'restaurant',
#   'gestion des voyages',
#   'voyage daffaires',
#   'restauration',
#   'gestion restauration',
#   'voyages loisirs'],
#  ['gestion des risques dentreprise',
#   'gestion de projet',
#   'gestion des risques',
#   'analyse des causes',
#   'amdec',
#   'ergonomie',
#   'gestion de crise',
#   'audit interne',
#   'management des processus',
#   'analyse fonctionnelle'],
#  ['cahier des charges fonctionnel',
#   'amdec',
#   'gestion de projet',
#   'analyse des besoins',
#   'analyse des exigences',
#   'automatisation des tests',
#   'automate programmable',
#   'analyse des risques',
#   'automatisation des processus',
#   'automatisme'],
#  ['technologie alimentaire',
#   'science alimentaire',
#   'secteur alimentaire',
#   'microbiologie alimentaire',
#   'transformation alimentaire',
#   'microbiologie',
#   'conception de produit',
#   'nourriture',
#   'chimie analytique',
#   'agroalimentaire'],
#  ['cartographie',
#   'sig',
#   'arcgis',
#   'topographie',
#   'qgis',
#   'science de lenvironnement',
#   'mapinfo',
#   'spatial analysis',
#   'geomatics',
#   'cartography'],
#  ['projektmanagement',
#   'finanzanalyse',
#   'wirtschaftswissenschaften',
#   'datenanalyse',
#   'finanzwesen',
#   'unternehmensanalyse',
#   'unternehmensstrategie',
#   'strategisches management',
#   'risikomanagement',
#   'finanzmodelle'],
#  ['adviseren',
#   'motiveren',
#   'luisteren',
#   'organiseren',
#   'samenwerken',
#   'verbinden',
#   'coachen',
#   'presenteren',
#   'schrijven',
#   'begeleiden'],
#  ['gestion de projet',
#   'gestion des risques',
#   'analyste commercial',
#   'politiques',
#   'gouvernement',
#   'recherche',
#   'reporting financier',
#   'finance dentreprise',
#   'planification de projets',
#   'statistiques'],
#  ['habillement',
#   'mode',
#   'stylisme',
#   'design mode',
#   'textile',
#   'merchandising visuel',
#   'articles de luxe',
#   'gestion de magasin',
#   'design textile',
#   'commerce de gros'],
#  ['advising',
#   'organising',
#   'ida',
#   'social issues',
#   'listening',
#   'digital pr',
#   'motivating others',
#   'consumer trends',
#   'extemporaneous speaking',
#   'global'],
#  ['strategic analysis',
#   'data analysis',
#   'category analysis',
#   'business analysis',
#   'financial analysis',
#   'metrics analysis',
#   'finance',
#   'management',
#   'variance analysis',
#   'process improvement'],
#  ['general business analysis',
#   'workflow diagrams',
#   'business impact analysis',
#   'user interface specifications',
#   'requirements workshops',
#   'experienced business analyst',
#   'use case',
#   'business analysis',
#   'post go live support',
#   'project communications'],
#  ['ssis',
#   'ssrs',
#   'microsoft sql server',
#   'ssas',
#   'mdx',
#   'olap',
#   'etl',
#   'business intelligence',
#   'data warehousing',
#   'performance point'],
#  ['administrator',
#   'researcher',
#   'lcmsandms',
#   'consultant',
#   'journalist',
#   'planner',
#   'keynote speaker',
#   'educator',
#   'opening new accounts',
#   'chemstation'],
#  ['allsource analysis',
#   'allsource intelligence',
#   'intelligence analysis',
#   'analyst notebook',
#   'briefing',
#   'palantir',
#   'siprnet',
#   'cidne',
#   'intelligence',
#   'falconview'],
#  ['cidne',
#   'falconview',
#   'intelligence analysis',
#   'palantir',
#   'allsource analysis',
#   'intelligence community',
#   'humint',
#   'intelligence',
#   'siprnet',
#   'allsource intelligence'],
#  ['industry analyst relations',
#   'messaging',
#   'thought leadership',
#   'corporate communications',
#   'message development',
#   'communication training',
#   'strategic counsel',
#   'crisis communications',
#   'media relations',
#   'strategic communications'],
#  ['processus commerciaux',
#   'analyse des exigences',
#   'gestion de projet',
#   'gestion des risques',
#   'gestion de projet logiciel',
#   'banque',
#   'gestion de portefeuille de projets',
#   'transformation des commerces',
#   'emprunts',
#   'management it'],
#  ['support analysts',
#   'programmers',
#   'developers',
#   'analyst notebook',
#   'researchers',
#   'experienced business analyst',
#   'analyst briefings',
#   'testers',
#   'multilanguage',
#   'project managers'],
#  ['root cause problem solving',
#   'problem analysis',
#   'general problem solving',
#   'handson problem solver',
#   'team problem solving',
#   'collaborative problem solving',
#   'crossfunctional problem solving',
#   'analysis of business problemsandneeds',
#   'systematic approach',
#   'cross functional team building'],
#  ['reporting metrics',
#   'budget models',
#   'reporting systems',
#   'reports analysis',
#   'call quality',
#   'profit analysis',
#   'accounts payableandrecievable',
#   'international reporting',
#   'excel dashboards',
#   'webi'],
#  ['thinking outside the box',
#   'bigpicture thinking',
#   'visual thinking',
#   'logical thinker',
#   'free thinking',
#   'strategic thinking',
#   'critical thinking',
#   'information seeking',
#   'quick thinker',
#   'inductive reasoning'],
#  ['analytical skills',
#   'cpsm',
#   'logical',
#   'decisive',
#   'diplomatic',
#   'productive',
#   'learner',
#   'communicative',
#   'practical',
#   'organized'],
#  ['analytical skills',
#   'highly adaptable',
#   'innovative problem solver',
#   'communication written',
#   'flexible working',
#   'independent thinker',
#   'attention to detail',
#   'oral communications',
#   'results oriented',
#   'systematic'],
#  ['analytical skills',
#   'detail orientation',
#   'results focused',
#   'stress resistant',
#   'influential',
#   'highly adaptable',
#   'innovative problem solver',
#   'quality oriented',
#   'innovative thinking',
#   'attention to detail'],
#  ['biochemistry',
#   'protein purification',
#   'molecular biology',
#   'hplc',
#   'protein assays',
#   'protein chromatography',
#   'analytical chemistry',
#   'microbiology',
#   'biotechnology',
#   'mass spectrometry'],
#  ['organizational capability',
#   'building organizational capability',
#   'thrives on challenges',
#   'flexible approach to work',
#   'solution orientated',
#   'capability development',
#   'vantive',
#   'third party relationships',
#   'client focus',
#   'leadership accountability'],
#  ['hplc',
#   'chemistry',
#   'chromatography',
#   'gas chromatography',
#   'wet chemistry',
#   'uvandvis',
#   'lcms',
#   'organic chemistry',
#   'gcms',
#   'mass spectrometry'],
#  ['analytical methods development',
#   'analytical chemistry',
#   'analytical method validation',
#   'instrumental analysis',
#   'gas chromatography',
#   'field instruments',
#   'analytical techniques',
#   'hplc',
#   'instrument validation',
#   'flame aa'],
#  ['analytical methods development',
#   'method transfer',
#   'hplc',
#   'method development',
#   'stability studies',
#   'analytical chemistry',
#   'dissolution',
#   'instrument validation',
#   'usp',
#   'gmp'],
#  ['analytical method validation',
#   'hplc',
#   'method transfer',
#   'analytical chemistry',
#   'analytical instruments',
#   'stability studies',
#   'dissolution testing',
#   'method development',
#   'chromatography',
#   'karl fisher'],
#  ['modelling tools',
#   'data analysis',
#   'energy modelling',
#   'excel models',
#   'resource modelling',
#   'management information',
#   'exploratory data analysis',
#   'discrete event simulation',
#   'business case modelling',
#   'aircraft performance'],
#  ['data interpretation',
#   'managing people',
#   'provision',
#   'exceptional project management skills',
#   'crossfunctional communication',
#   'detail orientation',
#   'effective communication skills',
#   'leadership qualities',
#   'interpersonal communications',
#   'corrective action'],
#  ['deductive reasoning',
#   'inductive reasoning',
#   'reasoning skills',
#   'analytical writing',
#   'logical thinker',
#   'critical thinking',
#   'logical approach',
#   'argumentation',
#   'high technical aptitude',
#   'attentiveness to detail'],
#  ['analytical abilities',
#   'highly analytical',
#   'analytical approach',
#   'analytical thinking',
#   'analytical',
#   'goal oriented',
#   'numerical ability',
#   'highly numerate',
#   'interpersonal skill',
#   'result oriented'],
#  ['chemstation',
#   'analytical chemistry',
#   'uv',
#   'hplc',
#   'wet chemistry',
#   'methods development',
#   'ph meter',
#   'chromatography',
#   'method development',
#   'gas chromatography'],
#  ['conceptual thinking',
#   'analytical skills',
#   'team collaboration',
#   'dependability',
#   'customer orientation',
#   'initiative',
#   'stress tolerance',
#   'complex problem solving',
#   'managing change',
#   'inductive reasoning'],
#  ['analytical reasoning',
#   'independent research',
#   'creative writing',
#   'research',
#   'academic editing',
#   'critical reading',
#   'reasoning',
#   'argumentation',
#   'critical thinking',
#   'persuasive communication'],
#  ['flexibilityandadaptabilityandmanaging multiple priorities',
#   'planningandorganizing',
#   'interpersonal abilities',
#   'computerandtechnical literacy',
#   'multicultural sensitivityandawareness',
#   'communications skills',
#   'willingness to learn',
#   'professionalism',
#   'loyalty',
#   'selfconfidence'],
#  ['predictive analytics',
#   'predictive modeling',
#   'chaid',
#   'customer analysis',
#   'segmentation',
#   'marketing mix modeling',
#   'customer analytics',
#   'business analytics',
#   'omniture',
#   'database marketing'],
#  ['marktforschung',
#   'projektmanagement',
#   'marktanalyse',
#   'quantitative sozialforschung',
#   'datenanalyse',
#   'unternehmensanalyse',
#   'strategisches management',
#   'onlinewerbung',
#   'digitales marketing',
#   'wettbewerbsanalyse'],
#  ['recherche en marketing',
#   'recherche quantitative',
#   'comportement du consommateur',
#   'analytics',
#   'programmation sas',
#   'statistiques web',
#   'data warehouse',
#   'esprit critique',
#   'statistiques',
#   'marketing mobile'],
#  ['resultaatgericht',
#   'creatief',
#   'besluitvaardig',
#   'communicatief',
#   'oplossingsgericht',
#   'integer',
#   'betrokken',
#   'klantgericht',
#   'doelgericht',
#   'empatisch'],
#  ['flexibiliteit',
#   'inlevingsvermogen',
#   'communicatieve vaardigheden',
#   'doorzettingsvermogen',
#   'resultaatgericht',
#   'plannen en organiseren',
#   'samenwerken',
#   'besluitvaardig',
#   'klantgerichtheid',
#   'organisatietalent'],
#  ['chemie',
#   'organische chemie',
#   'forschung und entwicklung',
#   'spektroskopie',
#   'biochemie',
#   'charakterisierung',
#   'wissenschaft',
#   'biowissenschaften',
#   'materialwissenschaft und werkstofftechnik',
#   'pharmaindustrie'],
#  ['requirements workshops',
#   'resolving conflicts',
#   'adapt quickly to change',
#   'timely execution',
#   'information gathering',
#   'maintenance inspections',
#   'written expression',
#   'research information',
#   'persuader',
#   'prioritize workload'],
#  ['nemo',
#   'actix',
#   'network performance',
#   'tems investigation',
#   'tems',
#   'fandg',
#   'transmitters',
#   'radio network planning',
#   'drive test',
#   'hsupa'],
#  ['researching',
#   'motivating',
#   'implementing',
#   'communicating',
#   'commitment',
#   'practical',
#   'listening',
#   'logical',
#   'prioritizing',
#   'organizing'],
#  ['surgical pathology',
#   'pathology',
#   'cytopathology',
#   'hematopathology',
#   'clinical pathology',
#   'histopathology',
#   'dermatopathology',
#   'laboratory medicine',
#   'molecular pathology',
#   'cytology'],
#  ['physiology',
#   'human anatomy',
#   'medical illustration',
#   'myofascial',
#   'neuromuscular',
#   'throat cultures',
#   'trigger point therapy',
#   'hydrotherapy',
#   'chair massage',
#   'myofascial release'],
#  ['news anchoring',
#   'compere',
#   'sports reporting',
#   'anchors',
#   'playbyplay',
#   'broadcast journalism',
#   'news reporting',
#   'avid newscutter',
#   'news',
#   'radio host'],
#  ['pile foundations',
#   'news anchoring',
#   'grouting',
#   'ground improvement',
#   'shallow foundations',
#   'anchoring',
#   'shotcrete',
#   'reporter',
#   'deep foundations',
#   'talk show'],
#  ['latin',
#   'ancient history',
#   'ancient philosophy',
#   'roman history',
#   'classics',
#   'greek',
#   'biblical hebrew',
#   'koine greek',
#   'mythology',
#   'history'],
#  ['ancient greek',
#   'roman history',
#   'latin',
#   'ancient philosophy',
#   'classics',
#   'archaeology',
#   'history',
#   'mythology',
#   'medieval history',
#   'historical archaeology'],
#  ['history of philosophy',
#   'ancient greek',
#   'continental philosophy',
#   'philosophy of mind',
#   'ancient history',
#   'philosophy of language',
#   'philosophy',
#   'political philosophy',
#   'philosophy of science',
#   'philosophy of religion'],
#  ['cohabitation',
#   'cohabitation agreements',
#   'family law',
#   'separation',
#   'legal advice',
#   'prenuptial agreements',
#   'children matters',
#   'injunctions',
#   'divorce law',
#   'dispute'],
#  ['generic programming',
#   'dissolution',
#   'regulatory affairs',
#   'sop',
#   'pharmaceutics',
#   'formulation',
#   'gmp',
#   'glp',
#   'pharmaceutical industry',
#   'cleaning validation'],
#  ['brew',
#   'ios',
#   'j2me',
#   'android ndk',
#   'ndk',
#   'java',
#   'android studio',
#   'symbian',
#   'android development',
#   'windows mobile'],
#  ['java',
#   'iphone application development',
#   'c',
#   'android development',
#   'mobile application development',
#   'javascript',
#   'web application development',
#   'android',
#   'bash scripting',
#   'php development'],
#  ['java',
#   'android sdk',
#   'windows phone development',
#   'ios development',
#   'android studio',
#   'c',
#   'iphone application development',
#   'ndk',
#   'j2me development',
#   'android'],
#  ['softwareentwicklung',
#   'java',
#   'webentwicklung',
#   'hmtl',
#   'mobilanwendungen',
#   'datenbanken',
#   'programmierung',
#   'agile methoden',
#   'javascript',
#   'softwareprojektleitung'],
#  ['c',
#   'android sdk',
#   'java',
#   'android',
#   'android development',
#   'jni',
#   'opengl es',
#   'eclipse',
#   'git',
#   'android studio'],
#  ['android development',
#   'java',
#   'android ndk',
#   'android studio',
#   'android',
#   'ndk',
#   'sqlite',
#   'c',
#   'javascript',
#   'desarrollo de programas para android'],
#  ...]

# %%
association_rules = apriori(domain, min_support=0.003, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for item in association_results:
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    print("Support: " + str(item[1]))

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: financial reporting -> accounting
# Support: 0.003110527407202599
# Confidence: 0.5454545454545454
# Lift: 109.59848484848484
# =====================================
# Rule: microsoft exchange -> active directory
# Support: 0.005322458007880003
# Confidence: 0.45294117647058824
# Lift: 81.90875
# =====================================
# Rule: vmware -> active directory
# Support: 0.003110527407202599
# Confidence: 0.2647058823529412
# Lift: 54.319148936170215
# =====================================
# Rule: windows 7 -> active directory
# Support: 0.0033178959010161054
# Confidence: 0.2823529411764706
# Lift: 54.82953020134228
# =====================================
# Rule: windows server -> active directory
# Support: 0.009850003456141563
# Confidence: 0.8382352941176471
# Lift: 69.29571428571428
# =====================================
# Rule: aspnet -> c
# Support: 0.003801755719914288
# Confidence: 0.8088235294117647
# Lift: 39.800170068027214
# =====================================
# Rule: aspnet -> microsoft sql server
# Support: 0.0038708785511854566
# Confidence: 0.823529411764706
# Lift: 111.34579439252337
# =====================================
# Rule: aspnet -> net
# Support: 0.003594387226100781
# Confidence: 0.7647058823529412
# Lift: 161.5036496350365
# =====================================
# Rule: c -> java
# Support: 0.005979124904956107
# Confidence: 0.2942176870748299
# Lift: 17.661606966438026
# =====================================
# Rule: javascript -> c
# Support: 0.004804036773346236
# Confidence: 0.23639455782312924
# Lift: 12.235849975052632
# =====================================
# Rule: microsoft sql server -> c
# Support: 0.0037326328886431188
# Confidence: 0.5046728971962616
# Lift: 24.833683005912643
# =====================================
# Rule: net -> c
# Support: 0.00397456279809221
# Confidence: 0.8394160583941604
# Lift: 41.305551417647344
# =====================================
# Rule: molecular biology -> cell culture
# Support: 0.004804036773346236
# Confidence: 0.8475609756097562
# Lift: 102.1805386178862
# =====================================
# Rule: cell culture -> pcr
# Support: 0.0030759659915670146
# Confidence: 0.5426829268292683
# Lift: 102.62737127371274
# =====================================
# Rule: western blotting -> cell culture
# Support: 0.0035252643948296123
# Confidence: 0.6219512195121951
# Lift: 149.9628048780488
# =====================================
# Rule: civil litigation -> litigation
# Support: 0.0033870187322872745
# Confidence: 0.9514563106796117
# Lift: 181.11471640265714
# =====================================
# Rule: javascript -> css
# Support: 0.007707195686735328
# Confidence: 0.802158273381295
# Lift: 41.5199418282905
# =====================================
# Rule: jquery -> css
# Support: 0.007534388608557406
# Confidence: 0.7841726618705036
# Lift: 75.12997284291772
# =====================================
# Rule: mysql -> css
# Support: 0.004112808460634548
# Confidence: 0.42805755395683454
# Lift: 41.2847242206235
# =====================================
# Rule: php -> css
# Support: 0.005011405267159743
# Confidence: 0.5215827338129496
# Lift: 70.19290614020412
# =====================================
# Rule: git -> javascript
# Support: 0.003767194304278703
# Confidence: 0.7077922077922078
# Lift: 36.63552726343424
# =====================================
# Rule: logo design -> graphic design
# Support: 0.0038708785511854566
# Confidence: 0.5544554455445544
# Lift: 138.29839535677704
# =====================================
# Rule: hibernate -> java
# Support: 0.005840879242413769
# Confidence: 0.9494382022471909
# Lift: 56.99386917805025
# =====================================
# Rule: maven -> hibernate
# Support: 0.0031450888228381833
# Confidence: 0.5112359550561797
# Lift: 132.07233146067415
# =====================================
# Rule: hibernate -> spring
# Support: 0.004112808460634548
# Confidence: 0.6685393258426966
# Lift: 151.12122542134833
# =====================================
# Rule: hibernate -> tomcat
# Support: 0.0032142116541093524
# Confidence: 0.5224719101123596
# Lift: 138.68992887331206
# =====================================
# Rule: photoshop -> illustrator
# Support: 0.003490702979194028
# Confidence: 0.6917808219178083
# Lift: 88.56631106800826
# =====================================
# Rule: java -> java enterprise edition
# Support: 0.003110527407202599
# Confidence: 0.8737864077669902
# Lift: 52.452564154211814
# =====================================
# Rule: javascript -> java
# Support: 0.007050528789659225
# Confidence: 0.42323651452282157
# Lift: 21.90684313274297
# =====================================
# Rule: maven -> java
# Support: 0.0035252643948296123
# Confidence: 0.21161825726141079
# Lift: 54.669309425014816
# =====================================
# Rule: mysql -> java
# Support: 0.0030414045759314303
# Confidence: 0.29333333333333333
# Lift: 17.608520055325034
# =====================================
# Rule: spring -> java
# Support: 0.004112808460634548
# Confidence: 0.24688796680497924
# Lift: 55.8082533713693
# =====================================
# Rule: tomcat -> java
# Support: 0.0035252643948296123
# Confidence: 0.21161825726141079
# Lift: 56.17396931744642
# =====================================
# Rule: jquery -> javascript
# Support: 0.009711757793599226
# Confidence: 0.5026833631484795
# Lift: 48.16106102429837
# =====================================
# Rule: mysql -> javascript
# Support: 0.007845441349277666
# Confidence: 0.40608228980322003
# Lift: 39.16528324388789
# =====================================
# Rule: php -> javascript
# Support: 0.006290177645676367
# Confidence: 0.32558139534883723
# Lift: 43.81568415359654
# =====================================
# Rule: mysql -> jquery
# Support: 0.005011405267159743
# Confidence: 0.4801324503311259
# Lift: 46.307174392935984
# =====================================
# Rule: php -> jquery
# Support: 0.005391580839151171
# Confidence: 0.5165562913907285
# Lift: 69.51646388418297
# =====================================
# Rule: manual testing -> regression testing
# Support: 0.003594387226100781
# Confidence: 0.9043478260869565
# Lift: 204.425
# =====================================
# Rule: manual testing -> test planning
# Support: 0.0031450888228381833
# Confidence: 0.7913043478260869
# Lift: 186.14308943089432
# =====================================
# Rule: windows server -> microsoft exchange
# Support: 0.005218773760973249
# Confidence: 0.94375
# Lift: 78.01846428571429
# =====================================
# Rule: net -> microsoft sql server
# Support: 0.0033178959010161054
# Confidence: 0.4485981308411215
# Lift: 94.74261545808035
# =====================================
# Rule: military -> military operations
# Support: 0.003110527407202599
# Confidence: 0.8035714285714286
# Lift: 221.43367346938777
# =====================================
# Rule: molecular biology -> pcr
# Support: 0.003905439966821041
# Confidence: 0.4708333333333334
# Lift: 89.03981481481482
# =====================================
# Rule: western blotting -> molecular biology
# Support: 0.003490702979194028
# Confidence: 0.4208333333333334
# Lift: 101.46993055555558
# =====================================
# Rule: mysql -> php
# Support: 0.005322458007880003
# Confidence: 0.5133333333333333
# Lift: 69.08272868217054
# =====================================
# Rule: test planning -> regression testing
# Support: 0.0036289486417363653
# Confidence: 0.8203125
# Lift: 192.96684451219514
# =====================================
# Rule: windows server -> vmware
# Support: 0.003490702979194028
# Confidence: 0.7163120567375887
# Lift: 59.21649442755826
# =====================================
# Rule: windows server -> microsoft exchange
# Support: 0.005045966682795327
# Confidence: 0.4294117647058823
# Lift: 82.28211920529802
# =====================================
# Rule: windows server -> vmware
# Support: 0.0030068431602958455
# Confidence: 0.25588235294117645
# Lift: 73.3039603960396
# =====================================
# Rule: aspnet -> microsoft sql server
# Support: 0.00335245731665169
# Confidence: 0.7132352941176471
# Lift: 191.08101851851853
# =====================================
# Rule: aspnet -> c
# Support: 0.0030414045759314303
# Confidence: 0.6470588235294118
# Lift: 162.8
# =====================================
# Rule: aspnet -> microsoft sql server
# Support: 0.0030414045759314303
# Confidence: 0.6470588235294118
# Lift: 195.02083333333334
# =====================================
# Rule: western blotting -> molecular biology
# Support: 0.003179650238473768
# Confidence: 0.5609756097560976
# Lift: 160.705626660227
# =====================================
# Rule: jquery -> javascript
# Support: 0.0070850902052948085
# Confidence: 0.737410071942446
# Lift: 75.92961929388873
# =====================================
# Rule: mysql -> javascript
# Support: 0.003940001382456626
# Confidence: 0.41007194244604317
# Lift: 52.26881754508288
# =====================================
# Rule: php -> javascript
# Support: 0.004492984032625977
# Confidence: 0.4676258992805756
# Lift: 74.34224049331964
# =====================================
# Rule: mysql -> jquery
# Support: 0.0038363171355498722
# Confidence: 0.39928057553956836
# Lift: 79.67437360456462
# =====================================
# Rule: php -> jquery
# Support: 0.004458422616990392
# Confidence: 0.46402877697841727
# Lift: 86.06543995572773
# =====================================
# Rule: mysql -> php
# Support: 0.0035252643948296123
# Confidence: 0.3669064748201439
# Lift: 68.93553209380548
# =====================================
# Rule: maven -> hibernate
# Support: 0.0030068431602958455
# Confidence: 0.4887640449438202
# Lift: 138.64606741573033
# =====================================
# Rule: spring -> hibernate
# Support: 0.003905439966821041
# Confidence: 0.6348314606741573
# Lift: 154.35473515248796
# =====================================
# Rule: hibernate -> tomcat
# Support: 0.0030759659915670146
# Confidence: 0.5
# Lift: 141.83333333333334
# =====================================
# Rule: mysql -> jquery
# Support: 0.004942282435888574
# Confidence: 0.2558139534883721
# Lift: 51.04635124298316
# =====================================
# Rule: php -> jquery
# Support: 0.005045966682795327
# Confidence: 0.26118067978533094
# Lift: 48.44231915967158
# =====================================
# Rule: mysql -> php
# Support: 0.004700352526439483
# Confidence: 0.24329159212880144
# Lift: 45.7103826406152
# =====================================
# Rule: mysql -> php
# Support: 0.004043685629363379
# Confidence: 0.3874172185430464
# Lift: 72.78915455405523
# =====================================
# Rule: mysql -> jquery
# Support: 0.003767194304278703
# Confidence: 0.3920863309352518
# Lift: 79.33304824671733
# =====================================
# Rule: php -> jquery
# Support: 0.004216492707541301
# Confidence: 0.4388489208633094
# Lift: 86.97023750862326
# =====================================
# Rule: mysql -> php
# Support: 0.00335245731665169
# Confidence: 0.3489208633093525
# Lift: 74.23291366906474
# =====================================
# Rule: mysql -> php
# Support: 0.00335245731665169
# Confidence: 0.3489208633093525
# Lift: 86.28783127344278
# =====================================
# Rule: mysql -> php
# Support: 0.00397456279809221
# Confidence: 0.20572450805008946
# Lift: 50.87549500787426
# =====================================
# Rule: css -> php
# Support: 0.003283334485380521
# Confidence: 0.34172661870503596
# Lift: 85.97841726618705
# =====================================
